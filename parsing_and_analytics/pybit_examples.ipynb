# %%
import os
import logging
from pybit.unified_trading import HTTP
from pybit import exceptions

# Логгинг уже встроен в pybit, его просто инициализировать
logging.basicConfig(
    format="%(asctime)s %(message)s",
    level=logging.DEBUG
)

# %%
# Создание клиента для подключения к API Bybit
# Важно, чтобы время сервера было правильным
API_KEY = os.getenv('API_KEY')
SECRET_KEY = os.getenv('SECRET_KEY')

cl = HTTP(
    api_key=API_KEY,
    api_secret=SECRET_KEY,
    demo=True
)
# Out:
# 2025-06-20 19:27:07,157 Initializing HTTP session.

# %%
cl.get_positions(category="linear", symbol="SOLUSDT")["result"]["list"][0]
# Out:
# 2025-06-20 19:29:05,617 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 857
# {'symbol': 'SOLUSDT',
#  'leverage': '10',
#  'autoAddMargin': 0,
#  'avgPrice': '145.69',
#  'liqPrice': '131.85',
#  'riskLimitValue': '50000',
#  'takeProfit': '',
#  'positionValue': '145.69',
#  'isReduceOnly': False,
#  'tpslMode': 'Full',
#  'riskId': 281,
#  'trailingStop': '0',
#  'unrealisedPnl': '0.07',
#  'markPrice': '145.76',
#  'adlRankIndicator': 2,
#  'cumRealisedPnl': '-4.24679885',
#  'positionMM': '0.80056655',
#  'createdTime': '1749535143946',
#  'positionIdx': 0,
#  'positionIM': '14.64111655',
#  'seq': 140710290618234,
#  'updatedTime': '1750429497920',
#  'side': 'Buy',
#  'bustPrice': '',
#  'positionBalance': '14.64111655',
#  'leverageSysUpdatedTime': '',
#  'curRealisedPnl': '-0.0801295',
#  'size': '1',
#  'positionStatus': 'Normal',
#  'mmrSysUpdatedTime': '',
#  'stopLoss': '',
#  'tradeMode': 0,
#  'sessionAvgPrice': ''}

# %%
# Открыта ли позиция
float(cl.get_positions(category="linear", symbol="SOLUSDT")["result"]["list"][0]['size'])
# Out:
# 2025-06-19 20:27:12,046 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 846
# 1.0

# %%
float(cl.get_positions(category="linear", symbol="SOLUSDT")["result"]["list"][0]["positionIM"] or 0)


# position_im = float(position_data.get("positionIM") or 0)
# Out:
# 2025-06-19 21:16:11,253 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 861
# 17.34443205

# %%
cl.get_positions(category="linear", symbol="SOLUSDT")["result"]["list"][0]
# Out:
# 2025-06-19 21:16:29,595 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 862
# {'symbol': 'SOLUSDT',
#  'leverage': '10',
#  'autoAddMargin': 0,
#  'avgPrice': '143.825',
#  'liqPrice': '130.17',
#  'riskLimitValue': '50000',
#  'takeProfit': '',
#  'positionValue': '172.59',
#  'isReduceOnly': False,
#  'tpslMode': 'Full',
#  'riskId': 281,
#  'trailingStop': '0',
#  'unrealisedPnl': '0.0912',
#  'markPrice': '143.901',
#  'adlRankIndicator': 2,
#  'cumRealisedPnl': '-3.8428295',
#  'positionMM': '0.94838205',
#  'createdTime': '1749535143946',
#  'positionIdx': 0,
#  'positionIM': '17.34443205',
#  'seq': 140710287770555,
#  'updatedTime': '1750349720402',
#  'side': 'Buy',
#  'bustPrice': '',
#  'positionBalance': '17.34443205',
#  'leverageSysUpdatedTime': '',
#  'curRealisedPnl': '-0.0949245',
#  'size': '1.2',
#  'positionStatus': 'Normal',
#  'mmrSysUpdatedTime': '',
#  'stopLoss': '',
#  'tradeMode': 0,
#  'sessionAvgPrice': ''}

# %%
symbol = "IPUSDT"
cl.get_positions(category="linear", symbol=symbol.upper())["result"]["list"]
# Out:
# 2025-06-19 20:49:56,325 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=IPUSDT HTTP/1.1" 200 692
# [{'symbol': 'IPUSDT',
#   'leverage': '10',
#   'autoAddMargin': 0,
#   'avgPrice': '',
#   'liqPrice': '',
#   'riskLimitValue': '5000',
#   'takeProfit': '',
#   'positionValue': '',
#   'tpslMode': '',
#   'isReduceOnly': False,
#   'riskId': 1,
#   'trailingStop': '',
#   'unrealisedPnl': '',
#   'markPrice': '',
#   'adlRankIndicator': 0,
#   'cumRealisedPnl': '',
#   'positionMM': '',
#   'createdTime': '',
#   'positionIdx': 0,
#   'positionIM': '',
#   'seq': -1,
#   'updatedTime': '',
#   'side': '',
#   'bustPrice': '',
#   'positionBalance': '',
#   'leverageSysUpdatedTime': '',
#   'curRealisedPnl': '',
#   'size': '0',
#   'positionStatus': '',
#   'mmrSysUpdatedTime': '',
#   'stopLoss': '',
#   'tradeMode': 0,
#   'sessionAvgPrice': ''}]

# %%
symbol = "SOLUSDT"
cl.get_positions(category="linear", symbol=symbol.upper())["result"]["list"]
# Out:
# 2025-06-19 20:44:02,546 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 794
# [{'symbol': 'SOLUSDT',
#   'leverage': '10',
#   'autoAddMargin': 0,
#   'avgPrice': '0',
#   'liqPrice': '',
#   'riskLimitValue': '50000',
#   'takeProfit': '',
#   'positionValue': '',
#   'isReduceOnly': False,
#   'tpslMode': 'Full',
#   'riskId': 281,
#   'trailingStop': '0',
#   'unrealisedPnl': '',
#   'markPrice': '143.34',
#   'adlRankIndicator': 0,
#   'cumRealisedPnl': '-3.4490486',
#   'positionMM': '0',
#   'createdTime': '1749535143946',
#   'positionIdx': 0,
#   'positionIM': '0',
#   'seq': 140710287698144,
#   'updatedTime': '1750347614414',
#   'side': '',
#   'bustPrice': '',
#   'positionBalance': '0',
#   'leverageSysUpdatedTime': '',
#   'curRealisedPnl': '0',
#   'size': '0',
#   'positionStatus': 'Normal',
#   'mmrSysUpdatedTime': '',
#   'stopLoss': '',
#   'tradeMode': 0,
#   'sessionAvgPrice': ''}]

# %%
# Начальная маржа позиции
pos_im = float(cl.get_positions(category="linear", symbol="SOLUSDT")["result"]["list"][0]["positionIM"])
if pos_im < 14.410983:
    print(pos_im)
# Out:
# 2025-06-19 20:31:03,365 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 844

# %%
# число открытых позиций на фьючерсах
len(cl.get_positions(category="linear", settleCoin='USDT')['result']['list'])
# Out:
# 2025-06-18 21:30:25,433 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&settleCoin=USDT HTTP/1.1" 200 None
# 2

# %%
decimals = 0.01
value = 50 / 140

factor = 1 / (10 ** decimals)
(value // factor) * factor
# Out:
# 0.0

# %%
cl.get_positions(category="linear", symbol="SOLUSDT")
# Out:
# 2025-06-18 21:25:47,862 https://api-demo.bybit.com:443 "GET /v5/position/list?category=linear&symbol=SOLUSDT HTTP/1.1" 200 859
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': 'SOLUSDT%2C1750263532226%2C0',
#   'category': 'linear',
#   'list': [{'symbol': 'SOLUSDT',
#     'leverage': '10',
#     'autoAddMargin': 0,
#     'avgPrice': '144.71',
#     'liqPrice': '130.97',
#     'riskLimitValue': '50000',
#     'takeProfit': '',
#     'positionValue': '14.471',
#     'isReduceOnly': False,
#     'tpslMode': 'Full',
#     'riskId': 281,
#     'trailingStop': '0',
#     'unrealisedPnl': '0.004',
#     'markPrice': '144.75',
#     'adlRankIndicator': 2,
#     'cumRealisedPnl': '-0.11861375',
#     'positionMM': '0.07951815',
#     'createdTime': '1749535143946',
#     'positionIdx': 0,
#     'positionIM': '1.45426315',
#     'seq': 140710284786956,
#     'updatedTime': '1750263532226',
#     'side': 'Buy',
#     'bustPrice': '',
#     'positionBalance': '1.45426315',
#     'leverageSysUpdatedTime': '',
#     'curRealisedPnl': '-0.00795905',
#     'size': '0.1',
#     'positionStatus': 'Normal',
#     'mmrSysUpdatedTime': '',
#     'stopLoss': '',
#     'tradeMode': 0,
#     'sessionAvgPrice': ''}]},
#  'retExtInfo': {},
#  'time': 1750263947766}

# %%
print(cl.get_server_time())
# Out:
# 2025-06-18 21:15:55,122 Starting new HTTPS connection (1): api-demo.bybit.com:443
# 2025-06-18 21:15:55,668 https://api-demo.bybit.com:443 "GET /v5/market/time HTTP/1.1" 200 134
# {'retCode': 0, 'retMsg': 'OK', 'result': {'timeSecond': '1750263355', 'timeNano': '1750263355569163777'}, 'retExtInfo': {}, 'time': 1750263355569}

# %%
# Получение данных стакана по фьючерсному контракту BTCUSDT (линейные деривативы)
response = cl.get_orderbook(
    category="linear",  # Категория: linear (USDT-счёт), inverse (BTC-счёт), spot
    symbol="BTCUSDT"
)
# Out:
# 2025-06-08 16:05:34,801 https://api-demo.bybit.com:443 "GET /v5/market/orderbook?category=linear&symbol=BTCUSDT HTTP/1.1" 200 None

# %% [markdown]
# Спот
# По умолчанию в qty при покупке указывается количество usdt, которое мы хотим потратить на покупку валюты
# Если на продажу, то передаем количество sol, которое хотим продать
#
# На деривативы и фьючерсы в qty передается именно валюта, а не стейблкоин
#
# можно изменить это поведение с помощью marketUnit (только на споте)

# %% [markdown]
# ### Спотовый рыночный ордер

# %%
r = cl.place_order(
    category="spot",
    symbol="SOLUSDT",
    side="Buy",
    order_type="Market",
    qty=10 # Трачу 10 баксов на солану
)
# Out:
# 2025-06-08 16:09:52,631 https://api-demo.bybit.com:443 "POST /v5/order/create HTTP/1.1" 200 143

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В ответе получаю orderId, который потом понадобится

# %%
r
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'orderId': '1968344861598027008',
#   'orderLinkId': '1968344861598027009'},
#  'retExtInfo': {},
#  'time': 1749380992542}

# %% [markdown]
# ### Получаю баланс на аккаунте

# %%
from pprint import pprint
balance = cl.get_wallet_balance(accountType="UNIFIED")

assets_balance = {
    el["coin"]: round(float(el["walletBalance"]), 4) # Количество знаков после запятой разное для пар
    for el in balance['result']['list'][0]['coin']
}
# Out:
# 2025-06-09 14:42:40,735 https://api-demo.bybit.com:443 "GET /v5/account/wallet-balance?accountType=UNIFIED HTTP/1.1" 200 None

# %% [markdown]
# Узнать дроби

# %%
cl.get_instruments_info(category="SPOT", symbol="SOLUSDT")
# Out:
# 2025-06-08 16:57:46,060 Resetting dropped connection: api-demo.bybit.com
# 2025-06-08 16:57:46,512 https://api-demo.bybit.com:443 "GET /v5/market/instruments-info?category=SPOT&symbol=SOLUSDT HTTP/1.1" 200 499
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'SPOT',
#   'list': [{'symbol': 'SOLUSDT',
#     'baseCoin': 'SOL',
#     'quoteCoin': 'USDT',
#     'innovation': '0',
#     'status': 'Trading',
#     'marginTrading': 'utaOnly',
#     'stTag': '0',
#     'lotSizeFilter': {'basePrecision': '0.001',
#      'quotePrecision': '0.00001',
#      'minOrderQty': '0.006',
#      'maxOrderQty': '48132.46053',
#      'minOrderAmt': '5',
#      'maxOrderAmt': '5000000'},
#     'priceFilter': {'tickSize': '0.01'},
#     'riskParameters': {'priceLimitRatioX': '0.02',
#      'priceLimitRatioY': '0.04'}}]},
#  'retExtInfo': {},
#  'time': 1749383866424}

# %% [markdown]
# basePrecision': '0.001 - значит солану мы можем продавать с точностью до 3го знака

# %%
assets_balance
# Out:
# {'USDC': 50000.0, 'BTC': 1.0, 'ETH': 1.0, 'SOL': 99.9, 'USDT': 34660.0058}

# %% [markdown]
# ### Продаю всю солану на балансе

# %%
r = cl.place_order(
    category="spot",
    symbol="SOLUSDT",
    side="Sell",
    order_type="Market",
    qty=assets_balance['SOL'] # Продаю всю солану
)
# Out:
# 2025-06-09 14:42:56,501 https://api-demo.bybit.com:443 "POST /v5/order/create HTTP/1.1" 200 143

# %% [markdown]
# ### Спотовый лимитный ордер

# %% [markdown]
# timeInForce Используем GTC
#
# 1. GTC (Good-Till-Cancelled) — "Действителен до отмены"
# Что это значит: Ордер будет оставаться в книге заявок, пока его либо полностью не исполнят, либо вы сами его не отмените.
#
# Пример: Вы выставили лимитный ордер на покупку BTC по цене ниже текущей. Ордер висит в ожидании, пока цена не достигнет вашей. Он будет ждать сколько угодно, пока не исполнится или пока вы его не отмените.
#
# Ордер может долго выполняться
#
# IOC и FOK испоняются моментально. В этом случае ордер исполняется моментально, но по цене не хуже той, которую мы задали
#
# IOC - позволяет взять столько, сколько дадут по заданной цене и закрыть ордер
# FOK - отдать нам все, что мы хотим по нашей цене, либо ничего
#
#
# https://chatgpt.com/share/6846a64b-9910-8003-8d42-1d9c9fe527bf

# %%
r = cl.place_order(
    category="spot",
    symbol="SOLUSDT",
    side="Buy",
    order_type="Limit",
    qty=1, # Покупаю 1 SOL
    price=100
)
# Out:
# 2025-06-09 14:45:20,467 https://api-demo.bybit.com:443 "POST /v5/order/create HTTP/1.1" 200 143

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Все Открытые ордера
cl.get_open_orders(category='spot')
# Открытые ордера по солане
cl.get_open_orders(category='spot', symbol='SOLUSDT')
# Out:
# 2025-06-09 14:47:45,431 https://api-demo.bybit.com:443 "GET /v5/order/realtime?category=spot HTTP/1.1" 200 None
# 2025-06-09 14:47:45,673 https://api-demo.bybit.com:443 "GET /v5/order/realtime?category=spot&symbol=SOLUSDT HTTP/1.1" 200 None
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '1969027088799501568%3A1749462320362%2C1969027088799501568%3A1749462320362',
#   'category': 'spot',
#   'list': [{'symbol': 'SOLUSDT',
#     'orderType': 'Limit',
#     'orderLinkId': '1969027088799501569',
#     'slLimitPrice': '0',
#     'orderId': '1969027088799501568',
#     'cancelType': 'UNKNOWN',
#     'avgPrice': '0.00',
#     'stopOrderType': '',
#     'lastPriceOnCreated': '',
#     'orderStatus': 'New',
#     'takeProfit': '0',
#     'cumExecValue': '0.00000',
#     'smpType': 'None',
#     'triggerDirection': 0,
#     'blockTradeId': '',
#     'isLeverage': '0',
#     'rejectReason': 'EC_NoError',
#     'price': '100.00',
#     'orderIv': '',
#     'createdTime': '1749462320362',
#     'tpTriggerBy': '',
#     'positionIdx': 0,
#     'trailingPercentage': '0',
#     'timeInForce': 'GTC',
#     'leavesValue': '100.00000',
#     'basePrice': '153.67',
#     'updatedTime': '1749462320362',
#     'side': 'Buy',
#     'smpGroup': 0,
#     'triggerPrice': '0.00',
#     'tpLimitPrice': '0',
#     'trailingValue': '0',
#     'cumExecFee': '0',
#     'leavesQty': '1',
#     'slTriggerBy': '',
#     'closeOnTrigger': False,
#     'placeType': '',
#     'cumExecQty': '0',
#     'reduceOnly': False,
#     'activationPrice': '0',
#     'qty': '1.000',
#     'stopLoss': '0',
#     'marketUnit': '',
#     'smpOrderId': '',
#     'triggerBy': ''}]},
#  'retExtInfo': {},
#  'time': 1749462465570}

# %% [markdown]
# list - список открытых ордеров
#
# Расшифровка полей
# https://bybit-exchange.github.io/docs/v5/order/open-order

# %%
# информация по конкретному id ордера
cl.get_open_orders(category='spot', orderId='1969027088799501568')
# Out:
# 2025-06-09 14:57:33,879 Resetting dropped connection: api-demo.bybit.com
# 2025-06-09 14:57:34,371 https://api-demo.bybit.com:443 "GET /v5/order/realtime?category=spot HTTP/1.1" 200 None
# 2025-06-09 14:57:34,615 https://api-demo.bybit.com:443 "GET /v5/order/realtime?category=spot&orderId=1969027088799501568 HTTP/1.1" 200 None
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '1969027088799501568%3A1749462320362%2C1969027088799501568%3A1749462320362',
#   'category': 'spot',
#   'list': [{'symbol': 'SOLUSDT',
#     'orderType': 'Limit',
#     'orderLinkId': '1969027088799501569',
#     'slLimitPrice': '0',
#     'orderId': '1969027088799501568',
#     'cancelType': 'UNKNOWN',
#     'avgPrice': '0.00',
#     'stopOrderType': '',
#     'lastPriceOnCreated': '',
#     'orderStatus': 'New',
#     'takeProfit': '0',
#     'cumExecValue': '0.00000',
#     'smpType': 'None',
#     'triggerDirection': 0,
#     'blockTradeId': '',
#     'isLeverage': '0',
#     'rejectReason': 'EC_NoError',
#     'price': '100.00',
#     'orderIv': '',
#     'createdTime': '1749462320362',
#     'tpTriggerBy': '',
#     'positionIdx': 0,
#     'trailingPercentage': '0',
#     'timeInForce': 'GTC',
#     'leavesValue': '100.00000',
#     'basePrice': '153.67',
#     'updatedTime': '1749462320362',
#     'side': 'Buy',
#     'smpGroup': 0,
#     'triggerPrice': '0.00',
#     'tpLimitPrice': '0',
#     'trailingValue': '0',
#     'cumExecFee': '0',
#     'leavesQty': '1',
#     'slTriggerBy': '',
#     'closeOnTrigger': False,
#     'placeType': '',
#     'cumExecQty': '0',
#     'reduceOnly': False,
#     'activationPrice': '0',
#     'qty': '1.000',
#     'stopLoss': '0',
#     'marketUnit': '',
#     'smpOrderId': '',
#     'triggerBy': ''}]},
#  'retExtInfo': {},
#  'time': 1749463054511}

# %%
# Отменяем ордер
cl.cancel_order(category='spot', orderId='1969027088799501568')
# Out:
# 2025-06-09 14:59:44,969 https://api-demo.bybit.com:443 "POST /v5/order/cancel HTTP/1.1" 200 143
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'orderId': '1969027088799501568',
#   'orderLinkId': '1969027088799501569'},
#  'retExtInfo': {},
#  'time': 1749463184864}

# %%
# Видно, что orderStatus теперь закрыт
cl.get_open_orders(category='spot', orderId='1969027088799501568')
# Out:
# 2025-06-09 15:00:10,754 https://api-demo.bybit.com:443 "GET /v5/order/realtime?category=spot&orderId=1969027088799501568 HTTP/1.1" 200 None
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '1969027088799501568%3A1749462320362%2C1969027088799501568%3A1749462320362',
#   'category': 'spot',
#   'list': [{'symbol': 'SOLUSDT',
#     'orderType': 'Limit',
#     'orderLinkId': '1969027088799501569',
#     'slLimitPrice': '0',
#     'orderId': '1969027088799501568',
#     'cancelType': 'CancelByUser',
#     'avgPrice': '0.00',
#     'stopOrderType': '',
#     'lastPriceOnCreated': '',
#     'orderStatus': 'Cancelled',
#     'takeProfit': '0',
#     'cumExecValue': '0.00000',
#     'smpType': 'None',
#     'triggerDirection': 0,
#     'blockTradeId': '',
#     'isLeverage': '0',
#     'rejectReason': 'EC_PerCancelRequest',
#     'price': '100.00',
#     'orderIv': '',
#     'createdTime': '1749462320362',
#     'tpTriggerBy': '',
#     'positionIdx': 0,
#     'trailingPercentage': '0',
#     'timeInForce': 'GTC',
#     'leavesValue': '100.00000',
#     'basePrice': '153.67',
#     'updatedTime': '1749463184864',
#     'side': 'Buy',
#     'smpGroup': 0,
#     'triggerPrice': '0.00',
#     'tpLimitPrice': '0',
#     'trailingValue': '0',
#     'cumExecFee': '0',
#     'leavesQty': '1',
#     'slTriggerBy': '',
#     'closeOnTrigger': False,
#     'placeType': '',
#     'cumExecQty': '0',
#     'reduceOnly': False,
#     'activationPrice': '0',
#     'qty': '1.000',
#     'stopLoss': '0',
#     'marketUnit': '',
#     'smpOrderId': '',
#     'triggerBy': ''}]},
#  'retExtInfo': {},
#  'time': 1749463210650}

# %%
# Удалить все ордера. Можно удалить по конкретной монете    
cl.cancel_all_orders(category='spot')
# Out:
# 2025-06-09 15:01:53,182 https://api-demo.bybit.com:443 "POST /v5/order/cancel-all HTTP/1.1" 200 99
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'list': [], 'success': '1'},
#  'retExtInfo': {},
#  'time': 1749463313078}

# %%
# Для лимитных орддеров можно получить текущую цену
price = float(cl.get_tickers(category="spot", symbol='SOLUSDT').get('result').get('list')[0].get('lastPrice'))
print(price)
# Out:
# 2025-06-09 15:05:49,088 https://api-demo.bybit.com:443 "GET /v5/market/tickers?category=spot&symbol=SOLUSDT HTTP/1.1" 200 407
# 153.55

# %%
from pump_monitor import PumpMonitor, PumpState

import decimal
import inspect
import time
from typing import Optional

from pybit import exceptions
from pybit.unified_trading import HTTP

class FuturesOrders:
    def __init__(self, cl, symbol):
        """
        Конструктор класса и инициализация
        - клиента pybit
        - получение параметров и фильтров Инструмента
        """
        self.cl = cl
        self.symbol = symbol
        self.category = "linear"
        self.price_decimals, self.qty_decimals, self.min_qty=self.get_filters()

    def get_filters(self):
        """
        Фильтры заданного инструмента
        - макс колво знаков в аргументах цены,
        - мин размер ордера в Базовой Валюте,
        - макс размер ордера в БВ
        """
        r = self.cl.get_instruments_info(symbol=self.symbol, category=self.category)
        c = r.get('result', {}).get('list', [])[0]
        # print(c)
        min_qty = c.get('lotSizeFilter', {}).get('minOrderQty', '0.0')
        qty_decimals = abs(decimal.Decimal(min_qty).as_tuple().exponent)
        price_decimals = int(c.get('priceScale', '4'))
        min_qty = float(min_qty)

        self.log(price_decimals, qty_decimals, min_qty)
        return price_decimals, qty_decimals, min_qty

    def get_price(self):
        """
        Один из способов получения текущей цены
        """
        r = float(self.cl.get_tickers(category=self.category, symbol=self.symbol).get('result').get('list')[0].get('ask1Price'))
        self.log(r)
        return r

    def get_position(self, key: Optional[str] = None):
        """
        Получаю текущую позицию
        :param key:
        :return:
        """
        r = self.cl.get_positions(category=self.category, symbol=self.symbol)
        p = r.get('result', {}).get('list', [])[0]
        qty = float(p.get('size', '0.0'))
        if qty <= 0.0: raise Exception("empty position")
        ret = dict(
            symbol=p.get('symbol'),
            avg_price=float(p.get('avgPrice', '0.0')),
            side=p.get('side'),
            unrel_pnl=float(p.get('unrealisedPnl', '0.0')),
            qty=qty
        )
        ret['rev_side'] = ("Sell", "Buy")[ret['side'] == 'Sell']
        self.log(ret)

        return ret.get(key) if key else ret

    def place_limit_order_by_percent(
            self,
            qty : float=0.00001,
            side : str="Sell",
            distance_perc : int=2,
            order_link_id : Optional[str]=None
    ):
        """
        Установка лимитного ордера по инструменту определенному в конструкторе класса
        в процентах от текущей цены
        в зависимости от направления лимитного ордера цена стопа расчитывается в разные стороны
        """
        curr_price =self.get_price()
        order_price = self.calculate_limit_price_perc(curr_price, side, distance_perc)
        if not order_link_id: order_link_id = f"FireflyX_{self.symbol}_{time.time()}"

        args = dict(
            category=self.category,
            symbol=self.symbol,
            side=side.capitalize(),
            orderType="Limit",
            qty=self.floor_qty(qty),
            price=self.floor_price(order_price),
            orderLinkId=order_link_id
        )
        self.log("args", args)

        r = self.cl.place_order(**args)
        self.log("result", r)

        return r

    def place_market_order_by_base(self, qty : float=0.00001, side : str="Sell"):
        """
        Размещение рыночного ордера с указанием размера ордера в Базовой Валюте (BTC, XRP, etc)
        :param qty:
        :param side:
        :return:
        """
        args = dict(
            category=self.category,
            symbol=self.symbol,
            side=side.capitalize(),
            orderType="Market",
            qty=self.floor_qty(qty),
            orderLinkId=f"FireflyX__{self.symbol}_{time.time()}"
        )
        self.log("args", args)

        r = self.cl.place_order(**args)
        self.log("result", r)

        return r

    def place_market_order_by_quote(self, quote: float=5.0, side: str="Sell"):
        """
        Отправка ордера с размером позиции в Котируемой Валюте (USDT напр)
        имеет смысл только для контрактов
        (для спота есть аргумент marketUnit, см. https://youtu.be/e7Np2ICYBzg )
        """
        curr_price = self.get_price()
        qty = self.floor_qty(quote / curr_price)
        if qty < self.min_qty: raise Exception(f"{qty} is to small")

        self.place_market_order_by_base(qty, side)


    def cancel_open_order_by_order_link_id(self, order_link_id):
        """
        Отменяю открытый ордер лимитка/алго
        по кастомному идентификатору
        """
        r = self.cl.cancel_order(category=self.category, symbol=self.symbol, orderLinkId=order_link_id)
        self.log(r)

        return r

    def cancel_all_open_orders(self):
        """
        Отмена всех открытых ордеров (лимитки и алго)
        по секции + инструмент
        """
        r = self.cl.cancel_all_orders(category=self.category, symbol=self.symbol)
        print("* cancel_all_open_orders", r)

    def close_position(self):
        """
        Полное закрытие текущей позиции
        """
        args = dict(
            category=self.category,
            symbol=self.symbol,
            side=self.get_position("rev_side"),
            orderType="Market",
            qty=0.0,
            orderLinkId=f"FireflyX__{self.symbol}_{time.time()}",
            reduceOnly=True,
            closeOnTrigger=True,
        )
        self.log("args", args)

        r = self.cl.place_order(**args)
        self.log("result", r)

    def log(self, *args):
        """
        Для удобного вывода из методов класса
        """
        caller = inspect.stack()[1].function
        print(f"* {caller}", self.symbol, "\n\t", args, "\n")

    def _floor(self, value, decimals):
        """
        Для аргументов цены нужно отбросить (округлить вниз)
        до колва знаков заданных в фильтрах цены
        """
        factor = 1 / (10 ** decimals)
        return round((value // factor) * factor, decimals)

    def floor_price(self, value):
        return self._floor(value, self.price_decimals)

    def floor_qty(self, value):
        return self._floor(value, self.qty_decimals)

    def calculate_limit_price_perc(self, price, side : str="Sell", distance_perc : int=2):
        """
        Расчет цен для постановки лимитного/алго ордера
        в процентах от заданной цены
        и в зависимости от направления
        :param price: Цена инструмента
        :param side: Sell/Buy
        :param distance_perc: колво процентов, мб отрицательным
        :return:
        """
        return price * (100 + ((-1, 1)[side.lower() == "sell"] * distance_perc)) / 100

# %%
cl = HTTP(api_key=API_KEY, api_secret=SECRET_KEY, demo=True)

symbols = ["solusdt"]

s_order_man = FuturesOrders(cl, symbols[0].upper())
# Out:
# * get_filters SOLUSDT
# 	 (3, 1, 0.1)

# %%
s_order_man.get_position()
# Out:
# * get_position SOLUSDT
# 	 ({'symbol': 'SOLUSDT', 'avg_price': 133.08, 'side': 'Buy', 'unrel_pnl': 0.24, 'qty': 1.0, 'rev_side': 'Sell'},)
# {'symbol': 'SOLUSDT',
#  'avg_price': 133.08,
#  'side': 'Buy',
#  'unrel_pnl': 0.24,
#  'qty': 1.0,
#  'rev_side': 'Sell'}
